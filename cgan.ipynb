# %% [markdown]
# ## Import libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import time

# %% [markdown]
# ## MNIST Dataset

# %%
(train_images, train_labels), (_, _) = tf.keras.datasets.mnist.load_data()

# %%
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype('float32')
train_images = (train_images - 127.5) / 127.5  # Normalize the images to [-1, 1]

# %% [markdown]
# ## Hyperparameters

# %%
BATCH_SIZE = 256
EPOCHS = 5000
NOISE_DIM = 100
TRAIN_RATIO = 5
INTERVAL = 200

# %% [markdown]
# ## Models

# %% [markdown]
# ### Generator

# %%
def make_generator_model():
    model = tf.keras.Sequential()

    ## Layers
    model.add(layers.Dense(7*7*256, use_bias=False, input_dim=100))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Reshape((7, 7, 256)))
    model.add(layers.Conv2DTranspose(128, (5, 5), strides=(1, 1), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False))
    model.add(layers.BatchNormalization())
    model.add(layers.LeakyReLU())

    model.add(layers.Conv2DTranspose(1, (5, 5), strides=(2, 2), padding='same', use_bias=False, activation='tanh'))

    ## Inputs
    noise = tf.keras.Input(shape=(NOISE_DIM,))
    label = tf.keras.Input(shape=(1,), dtype='int32')
    label_embedding = layers.Flatten()(layers.Embedding(10, 100)(label))

    ## Concatenate noise and label
    model_input = layers.multiply([noise, label_embedding])

    ## Output
    image = model(model_input)

    return tf.keras.Model([noise, label], image)

# %%
generator = make_generator_model()

noise = tf.random.normal([1, 100])
label = tf.random.uniform([1], minval=0, maxval=9, dtype=tf.int32)
generated_image = generator([noise, label], training=False)

plt.imshow(generated_image[0, :, :, 0], cmap='gray')

# %%
generator.summary()
# Out:
# Model: "model_34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_70 (InputLayer)          [(None, 1)]          0           []
#
#  embedding_24 (Embedding)       (None, 1, 100)       1000        ['input_70[0][0]']
#
#  input_69 (InputLayer)          [(None, 100)]        0           []
#
#  flatten_46 (Flatten)           (None, 100)          0           ['embedding_24[0][0]']
#
#  multiply_24 (Multiply)         (None, 100)          0           ['input_69[0][0]',
#                                                                   'flatten_46[0][0]']
#
#  sequential_24 (Sequential)     (None, 28, 28, 1)    2330944     ['multiply_24[0][0]']
#
# ==================================================================================================
# Total params: 2,331,944
# Trainable params: 2,306,472
# Non-trainable params: 25,472
# __________________________________________________________________________________________________

# %% [markdown]
# ### Discriminator

# %%
def make_discriminator_model():
    model = tf.keras.Sequential()

    ##Layers
    model.add(layers.Reshape((28, 28, 1), input_shape=(784,)))
    
    model.add(layers.Conv2D(64, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (5, 5), strides=(2, 2), padding='same'))
    model.add(layers.LeakyReLU())
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation='sigmoid'))

    ## Inputs
    image = tf.keras.Input(shape=(28,28,1))
    flat_img = layers.Flatten()(image)

    label = tf.keras.Input(shape=(1,), dtype='int32')
    label_embedding = layers.Flatten()(layers.Embedding(10, 784)(label))

    model_input = layers.multiply([flat_img, label_embedding])

    ## Output
    validity = model(model_input)

    return tf.keras.Model([image,label], validity)

# %%
discriminator = make_discriminator_model()
decision = discriminator([generated_image, label])
print (decision)
# Out:
# tf.Tensor([[0.49999976]], shape=(1, 1), dtype=float32)

# %%
discriminator.summary()
# Out:
# Model: "model_35"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_72 (InputLayer)          [(None, 1)]          0           []
#
#  input_71 (InputLayer)          [(None, 28, 28, 1)]  0           []
#
#  embedding_25 (Embedding)       (None, 1, 784)       7840        ['input_72[0][0]']
#
#  flatten_48 (Flatten)           (None, 784)          0           ['input_71[0][0]']
#
#  flatten_49 (Flatten)           (None, 784)          0           ['embedding_25[0][0]']
#
#  multiply_25 (Multiply)         (None, 784)          0           ['flatten_48[0][0]',
#                                                                   'flatten_49[0][0]']
#
#  sequential_25 (Sequential)     (None, 1)            212865      ['multiply_25[0][0]']
#
# ==================================================================================================
# Total params: 220,705
# Trainable params: 220,705
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Utility

# %%
def sample_images(epoch):
    r, c = 2, 5
    noise = np.random.normal(0, 1, (r * c, 100))
    sampled_labels = np.arange(0, 10).reshape(-1, 1)

    gen_imgs = generator.predict([noise, sampled_labels])

    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt,:,:,0], cmap='gray')
            axs[i,j].set_title("Digit: %d" % sampled_labels[cnt])
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("samples/%d.png" % epoch)
    plt.close()

# %%
def train_ratio(epoch):
    if epoch < 1500:
        return TRAIN_RATIO
    else:
        return max(1,TRAIN_RATIO *(0.5)**((epoch-1500)//100))

# %% [markdown]
# ## Loss Functions and Optimizers

# %%
optimizer = tf.keras.optimizers.Adam(1e-4)
loss_object = tf.keras.losses.BinaryCrossentropy()

# %%
## Discriminator setup
discriminator.compile(optimizer=optimizer, loss=loss_object, metrics=['accuracy'])
discriminator.trainable = False

# %%
## Generator setup
noise = layers.Input(shape=(NOISE_DIM,))
label = layers.Input(shape=(1,), dtype='int32')
image = generator([noise, label])

## Combined model
validity = discriminator([image, label])
combined = tf.keras.Model([noise, label], validity)
combined.compile(optimizer=optimizer, loss=loss_object)

# %% [markdown]
# ## Training the model

# %%
real = np.ones((BATCH_SIZE, 1))
fake = np.zeros((BATCH_SIZE, 1))

discriminator_loss = []
generator_loss = []

# %%
for epoch in range(EPOCHS):
    print(f"----------- Epoch {epoch+1} -----------")

    idx = np.random.randint(0, train_images.shape[0], BATCH_SIZE)
    imgs, labels = train_images[idx], train_labels[idx]

    noise = np.random.normal(0, 1, (BATCH_SIZE, 100))

    if(epoch % train_ratio(epoch+1) == 0):
        discriminator.trainable = True
    
    gen_imgs = generator.predict([noise, labels])

    d_loss_real = discriminator.train_on_batch([imgs, labels], real)
    d_loss_fake = discriminator.train_on_batch([gen_imgs, labels], fake)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    discriminator_loss.append(d_loss[0])

    discriminator.trainable = False

    g_loss = combined.train_on_batch([noise, labels], real)

    generator_loss.append(g_loss)

    print(f"Discriminator loss: {d_loss[0]}   Accuracy: {d_loss[1]}")
    print(f"Generator loss: {g_loss}")
    print('---------------------------------------')

    if((epoch+1) % INTERVAL==0):
        sample_images(epoch+1)
# Out:
# ----------- Epoch 1 -----------
# 8/8 [==============================] - 1s 27ms/step
# Discriminator loss: 0.693110466003418   Accuracy: 0.341796875
# Generator loss: 0.6917192339897156
# ---------------------------------------
# ----------- Epoch 2 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6917901635169983   Accuracy: 0.486328125
# Generator loss: 0.6908782720565796
# ---------------------------------------
# ----------- Epoch 3 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6907274425029755   Accuracy: 0.5
# Generator loss: 0.690388560295105
# ---------------------------------------
# ----------- Epoch 4 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6898153722286224   Accuracy: 0.5
# Generator loss: 0.6897260546684265
# ---------------------------------------
# ----------- Epoch 5 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.6889367997646332   Accuracy: 0.5
# Generator loss: 0.6888977289199829
# ---------------------------------------
# ----------- Epoch 6 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6880126595497131   Accuracy: 0.5
# Generator loss: 0.687814474105835
# ---------------------------------------
# ----------- Epoch 7 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.686831146478653   Accuracy: 0.5
# Generator loss: 0.6867889165878296
# ---------------------------------------
# ----------- Epoch 8 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.6857284009456635   Accuracy: 0.5
# Generator loss: 0.6854201555252075
# ---------------------------------------
# ----------- Epoch 9 -----------
# 8/8 [==============================] - 0s 13ms/step
# Discriminator loss: 0.6845998764038086   Accuracy: 0.5
# Generator loss: 0.6838154792785645
# ---------------------------------------
# ----------- Epoch 10 -----------
# 8/8 [==============================] - 0s 13ms/step
# Discriminator loss: 0.6831719279289246   Accuracy: 0.5
# Generator loss: 0.6821742057800293
# ---------------------------------------
# ----------- Epoch 11 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6818593442440033   Accuracy: 0.5
# Generator loss: 0.6797997951507568
# ---------------------------------------
# ----------- Epoch 12 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6803260147571564   Accuracy: 0.5
# Generator loss: 0.6772987246513367
# ---------------------------------------
# ----------- Epoch 13 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6787537336349487   Accuracy: 0.5
# Generator loss: 0.6744053363800049
# ---------------------------------------
# ----------- Epoch 14 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6767807602882385   Accuracy: 0.5
# Generator loss: 0.6710840463638306
# ---------------------------------------
# ----------- Epoch 15 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.6745571196079254   Accuracy: 0.5
# Generator loss: 0.6676416993141174
# ---------------------------------------
# ----------- Epoch 16 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.6723480820655823   Accuracy: 0.5
# Generator loss: 0.663582444190979
# ---------------------------------------
# ----------- Epoch 17 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0
-----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.5444996803998947   Accuracy: 0.5078125
# Generator loss: 0.4095359444618225
# ---------------------------------------
# ----------- Epoch 41 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.536140576004982   Accuracy: 0.53515625
# Generator loss: 0.39520570635795593
# ---------------------------------------
# ----------- Epoch 42 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.5282483845949173   Accuracy: 0.615234375
# Generator loss: 0.3798392117023468
# ---------------------------------------
# ----------- Epoch 43 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.5202389061450958   Accuracy: 0.701171875
# Generator loss: 0.3653090298175812
# ---------------------------------------
# ----------- Epoch 44 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.5128454715013504   Accuracy: 0.853515625
# Generator loss: 0.3530399203300476
# ---------------------------------------
# ----------- Epoch 45 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.502735048532486   Accuracy: 0.9296875
# Generator loss: 0.3381376266479492
# ---------------------------------------
# ----------- Epoch 46 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.4957016408443451   Accuracy: 0.970703125
# Generator loss: 0.32591813802719116
# ---------------------------------------
# ----------- Epoch 47 -----------
# 8/8 [==============================] - 0s 12ms/step
# Discriminator loss: 0.48798324167728424   Accuracy: 0.9921875
# Generator loss: 0.3127898871898651
# ---------------------------------------
# ----------- Epoch 48 -----------
# 8/8 [==============================] - 0s 12ms/step
# Discriminator loss: 0.4797022044658661   Accuracy: 0.99609375
# Generator loss: 0.3002254366874695
# ---------------------------------------
# ----------- Epoch 49 -----------
# 8/8 [==============================] - 0s 13ms/step
# Discriminator loss: 0.4715531915426254   Accuracy: 1.0
# Generator loss: 0.28888872265815735
# ---------------------------------------
# ----------- Epoch 50 -----------
# 8/8 [==============================] - 0s 12ms/step
# Discriminator loss: 0.46198318153619766   Accuracy: 1.0
# Generator loss: 0.27931898832321167
# ---------------------------------------
# ----------- Epoch 51 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.4557884931564331   Accuracy: 1.0
# Generator loss: 0.269289493560791
# ---------------------------------------
# ----------- Epoch 52 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.4465934783220291   Accuracy: 1.0
# Generator loss: 0.25943803787231445
# ---------------------------------------
# ----------- Epoch 53 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.43983443081378937   Accuracy: 1.0
# Generator loss: 0.24850261211395264
# ---------------------------------------
# ----------- Epoch 54 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.43229950964450836   Accuracy: 1.0
# Generator loss: 0.24196121096611023
# ---------------------------------------
# ----------- Epoch 55 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.42275530844926834   Accuracy: 1.0
# Generator loss: 0.23642894625663757
# ---------------------------------------
# ----------- Epoch 56 -----------
# 8/8 [==============================] - 0s 12ms/step
# Discriminator loss: 0.4162632152438164   Accuracy: 1.0
# Generator loss: 0.2275753617286682
# ---------------------------------------
# ----------- Epoch 57 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.4079190194606781   Accuracy: 1.0
# Generator loss: 0.22143499553203583
# ---------------------------------------
# ----------- Epoch 58 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.40011948347091675   Accuracy: 1.0
# Generator loss: 0.2148265242576599
# ---------------------------------------
# ----------- Epoch 59 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.3907144367694855   Accuracy: 1.0
# Generator loss: 0.21286050975322723
# ---------------------------------------
# ----------- Epoch 60 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.3837793171405792   Accuracy: 1.0
# Generator loss: 0.20847229659557343
# ---------------------------------------
# ----------- Epoch 61 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.3755750060081482   Accuracy: 1.0
# Generator loss: 0.20353931188583374
# ---------------------------------------
# ----------- Epoch 62 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.36885038018226624   Accuracy: 1.0
# Generator loss: 0.2030029594898224
# ---------------------------------------
# ----------- Epoch 63 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.35984282940626144   Accuracy: 1.0
# Generator loss: 0.2049122005701065
# ---------------------------------------
# ----------- Epoch 64 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.3534644842147827   Accuracy: 1.0
# Generator loss: 0.20123574137687683
# ---------------------------------------
# ----------- Epoch 65 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.34498897194862366   Accuracy: 1.0
# Generator loss: 0.20127078890800476
# ---------------------------------------
# ----------- Epoch 66 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.3372469134628773   Accuracy: 1.0
# Generator loss: 0.20015378296375275
# ---------------------------------------
# ----------- Epoch 67 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.3273029401898384   Accuracy: 1.0
# Generator loss: 0.2072870135307312
# ---------------------------------------
# ----------- Epoch 68 -----------
# 8/8 [==============================] - 0s 8ms/step
# Discriminator loss: 0.32015130668878555   Accuracy: 1.0
# Generator loss: 0.20573613047599792
# ---------------------------------------
# ----------- Epoch 69 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.30982988327741623   Accuracy: 1.0
# Generator loss: 0.21298213303089142
# ---------------------------------------
# ----------- Epoch 70 -----------
# 8/8 [==============================] - 0s 12ms/step
# Discriminator loss: 0.30149615556001663   Accuracy: 1.0
# Generator loss: 0.20880642533302307
# ---------------------------------------
# ----------- Epoch 71 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.29243356361985207   Accuracy: 1.0
# Generator loss: 0.2160196602344513
# ---------------------------------------
# ----------- Epoch 72 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.2832462079823017   Accuracy: 1.0
# Generator loss: 0.2251276671886444
# ---------------------------------------
# ----------- Epoch 73 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.27429914474487305   Accuracy: 1.0
# Generator loss: 0.22723053395748138
# ---------------------------------------
# ----------- Epoch 74 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.2658532075583935   Accuracy: 1.0
# Generator loss: 0.2295415997505188
# ---------------------------------------
# ----------- Epoch 75 -----------
# 8/8 [==============================] - 0s 11ms/step
# Discriminator loss: 0.2556980848312378   Accuracy: 1.0
# Generator loss: 0.23565566539764404
# ---------------------------------------
# ----------- Epoch 76 -----------
# 8/8 [==============================] - 0s 9ms/step
# Discriminator loss: 0.24373343214392662   Accuracy: 1.0
# Generator loss: 0.24387727677822113
# ---------------------------------------
# ----------- Epoch 77 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.23516524583101273   Accuracy: 1.0
# Generator loss: 0.249543234705925
# ---------------------------------------
# ----------- Epoch 78 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.2244778759777546   Accuracy: 1.0
# Generator loss: 0.24521633982658386
# ---------------------------------------
# ----------- Epoch 79 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.21545402519404888   Accuracy: 1.0
# Generator loss: 0.2471340298652649
# ---------------------------------------
# ----------- Epoch 80 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0.2062130905687809   Accuracy: 1.0
# Generator loss: 0.2466001659631729
# ---------------------------------------
# ----------- Epoch 81 -----------
# 8/8 [==============================] - 0s 10ms/step
# Discriminator loss: 0